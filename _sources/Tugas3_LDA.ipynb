# %% [markdown]
# # LDA

# %%
from sklearn.decomposition import LatentDirichletAllocation
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/drive/MyDrive/ppw/PTA.csv')
df
# Out:
#      Unnamed: 0                                              Judul  \
# 0             0  Pengembangan Game Edukasi 2 Dimensi Untuk Mate...
# 1             1  Pengembangan Media Pembelajaran Sistem Bilanga...
# 2             2  PENGARUH MEDIA PEMBELAJARAN E-LEARNING BERBASI...
# 3             3  PROFIL BERPIKIR KRITIS SISWA KELAS X TKJ DITIN...
# 4             4  PENGEMBANGAN GAME EDUKASI 3D STRUKTUR ALGORITM...
# ..          ...                                                ...
# 340         340  PENGEMBANGAN APLIKASI STUDENT ASSISTANT BERBAS...
# 341         341  ANALISIS PEMECAHAN MASALAH KONVERSI BILANGAN B...
# 342         342  PENGEMBANGAN PERANGKAT MODEL PEMBELAJARAN KOOP...
# 343         343  Pengembangan Perangkat Model Pembelajaran Visu...
# 344         344  PENGEMBANGAN PERANGKAT MODEL PEMBELAJARAN LAPS...
#
#                      Nama Penulis                       Pembimbing I  \
# 0    Nurrohmat Hidayatullah Akbar       Arik Kurniawati, S.Kom. M.T.
# 1                        Cholilah       Arik Kurniawati, S.kom., MT.
# 2                 TAUFIKUR RAHMAN       MEDIKA RISNASARI, S.ST.,M.T.
# 3                 Yuliana Wardani     Puji Rahayu Ningsih,S.Pd.,M.Pd
# 4                   Deny Prasetyo    Arik Kurniawati, S. Kom., M. T.
# ..                            ...                                ...
# 340           Arbi Wahyu Eko Jati      Medika Risnasari, S.ST., M.T.
# 341         Magfiroh Kharim Paref        Muchamad Arif, S.Pd., M.Pd.
# 342                  SITI SAMIYAH   Puji Rahayu Ningsih, S.Pd., M.Pd
# 343        Mukhamad Dani Setyawan  Ariesta Kartika Sari, S.Si., M.Pd
# 344         UMI LATHIFATUL FITRIA       Medika Risnasari, S.ST., M.T
#
#                           Pembimbing II  \
# 0     Puji Rahayu Ningsih, S.Pd., M.Pd.
# 1          Wanda Ramansyah, S.Pd., M.Pd
# 2            MUCHAMAD ARIF, S.PD.,M.PD.
# 3          Sigit Dwi Saputo, S.Pd.,M.Pd
# 4      Sigit Dwi Saputro, S.Pd., M. Pd.
# ..                                  ...
# 340  Muhamad Afif Effindi, S.Kom., M.T.
# 341           Nuru Aini, S.Kom., M.Kom.
# 342        Laili Cahyani, S.Kom., M.Kom
# 343            Nuru Aini, S.Kom., M.Kom
# 344   Etistika Yuni Wijaya, S.Pd., M.Pd
#
#                                                Abstrak
# 0    Materi struktur dasar algoritma pemrograman me...
# 1    Pada Mata Pelajaran Sistem Komputer, siswa har...
# 2    Penelitian ini bertujuan untuk mengetahui peng...
# 3    Abstrak\nPenelitian ini bertujuan untuk menget...
# 4    Mata pelajaran pemrograman dasar merupakan sal...
# ..                                                 ...
# 340  Kegiatan belajar mengajar adalah suatu rutinin...
# 341  Penelitian ini bertujuan untuk menganalisis ke...
# 342  ABSTRAK\nIlmu pengetahuan dan teknologi berkem...
# 343  Abstrak \nMasalah dalam penelitian ini antara ...
# 344  Penggunaan model pembelajaran yang tepat untuk...
#
# [345 rows x 6 columns]

# %%
X = df.drop('/content/drive/MyDrive/ppw/PTA.csv',axis=1)
X
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-56975216b531> in <cell line: 1>()
# ----> 1 X = df.drop('/content/drive/MyDrive/ppw/PTA.csv',axis=1)
#       2 X
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503         for axis, labels in axes.items():
#    4504             if labels is not None:
# -> 4505                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4506
#    4507         if inplace:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4544                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4545             else:
# -> 4546                 new_axis = axis.drop(labels, errors=errors)
#    4547             indexer = axis.get_indexer(new_axis)
#    4548
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6932         if mask.any():
#    6933             if errors != "ignore":
# -> 6934                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935             indexer = indexer[~mask]
#    6936         return self.delete(indexer)
#
# KeyError: "['/content/drive/MyDrive/ppw/PTA.csv'] not found in axis"

# %%
print("Judul:", article_row_title)
article_row_title = table_article_row.find('a', attrs = {"class":"title", "href":"#"}).string
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-977281198b01> in <cell line: 1>()
# ----> 1 print("Judul:", article_row_title)
#       2 article_row_title = table_article_row.find('a', attrs = {"class":"title", "href":"#"}).string
#
# NameError: name 'article_row_title' is not defined

# %%
k = 3
alpha = 0.1
beta = 0.2

lda = LatentDirichletAllocation(n_components=k, doc_topic_prior=alpha, topic_word_prior=beta)
proporsi_topik_dokumen = lda.fit_transform(X)

# %%
dokumen = df['Dokumen']
output_proporsi_TD = pd.DataFrame(proporsi_topik_dokumen, columns=['Topik 1', 'Topik 2', 'Topik 3',])
output_proporsi_TD.insert(0,'Dokumen', dokumen)
output_proporsi_TD
# Out:
#                                                Dokumen   Topik 1   Topik 2  \
# 0    sistem informasi akademik siakad sistem inform...  0.001215  0.272808
# 1    berjalannya koneksi jaringan komputer lancar g...  0.000950  0.348276
# 2    web server perangkat lunak server berfungsi me...  0.000915  0.000915
# 3    penjadwalan kuliah perguruan kompleks permasal...  0.997028  0.001486
# 4    seiring perkembangan teknologi didunia muncul ...  0.138216  0.001201
# ..                                                 ...       ...       ...
# 823  kurangnya pemahaman gejala penyakit saluran pe...  0.837054  0.162121
# 824  data set hilang utama studi bersifat substansi...  0.001246  0.997509
# 825  proses seleksi penerimaan tenaga kerja faktor ...  0.000636  0.998728
# 826  sapi salah hewan ternak komoditi utama bahan p...  0.000774  0.998453
# 827  sistem temu informasi alternatif metode simila...  0.001108  0.918902
#
#       Topik 3
# 0    0.725976
# 1    0.650774
# 2    0.998170
# 3    0.001486
# 4    0.860583
# ..        ...
# 823  0.000825
# 824  0.001246
# 825  0.000636
# 826  0.000773
# 827  0.079990
#
# [828 rows x 4 columns]

# %%
df.columns.shape
# Out:
# (8722,)

# %%
# Output distribusi kata pada topik
distribusi_kata_topik = pd.DataFrame(lda.components_)
distribusi_kata_topik
# Out:
#        0         1     2     3         4        5     6         7     \
# 0  1.190398  2.194377   0.2   1.2  2.199463  0.21795   0.2  0.220674
# 1  0.205715  0.200000   0.2   0.2  0.200000  0.20000   3.2  4.193551
# 2  0.203887  0.205623   1.2   1.2  0.200537  1.18205   0.2  2.185775
#
#        8         9     ...      8711  8712      8713  8714      8715     8716  \
# 0  0.200000  0.264233  ...  2.199317   0.2  0.200000   0.2  0.200000  0.20000
# 1  1.197447  0.200000  ...  0.200000   0.2  0.205267  16.2  8.194058  0.20425
# 2  0.202553  5.135767  ...  0.200683   1.2  1.194733   0.2  0.205942  3.19575
#
#        8717  8718  8719  8720
# 0  0.200000   3.2   1.2   1.2
# 1  0.204134   0.2   0.2   0.2
# 2  4.195866   0.2   0.2   0.2
#
# [3 rows x 8721 columns]
