# %%
# %pwd
# Out:
# '/content'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/prosaindata
# Out:
# /content/drive/MyDrive/prosaindata

# %%
# !pip install jupyter-book
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !git config --global user.name "elmatiaaa"
# !git config --global user.email "elmatia113@gmail.com"
# !git config --global user.password "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"

# %%
! git config -l
# Out:
# filter.lfs.clean=git-lfs clean -- %f
# filter.lfs.smudge=git-lfs smudge -- %f
# filter.lfs.process=git-lfs filter-process
# filter.lfs.required=true
# user.name=elmatiaaa
# user.email=elmatia113@gmail.com
# user.password=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

# %%
# !jupyter-book create tugas/
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/jupyter-book", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.10/dist-packages/click/core.py", line 1130, in __call__
#     return self.main(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/click/core.py", line 1055, in main
#     rv = self.invoke(ctx)
#   File "/usr/local/lib/python3.10/dist-packages/click/core.py", line 1657, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#   File "/usr/local/lib/python3.10/dist-packages/click/core.py", line 1404, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#   File "/usr/local/lib/python3.10/dist-packages/click/core.py", line 760, in invoke
#     return __callback(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/jupyter_book/cli/main.py", line 334, in create
#     sh.copytree(template_path, book)
#   File "/usr/lib/python3.10/shutil.py", line 559, in copytree
# ...

# %%
# %cd /content/drive/MyDrive/prosaindata/tugas
# Out:
# /content/drive/MyDrive/prosaindata/tugas

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/prosaindata/tugas/.git/

# %%
# !git remote add origin https://elmatiaaa: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@github.com/elmatiaaa/prosaindata.git
# Out:
# fatal: remote origin already exists.

# %%
# !git remote -v
# Out:
# origin	https://elmatiaaa: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@github.com/elmatiaaa/prosaindata.git (fetch)
# origin	https://elmatiaaa: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@github.com/elmatiaaa/prosaindata.git (push)

# %%
# !git config -l
# Out:
# filter.lfs.clean=git-lfs clean -- %f
# filter.lfs.smudge=git-lfs smudge -- %f
# filter.lfs.process=git-lfs filter-process
# filter.lfs.required=true
# user.name=elmatiaaa
# user.email=elmatia113@gmail.com
# user.password=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
# core.repositoryformatversion=0
# core.filemode=true
# core.bare=false
# core.logallrefupdates=true
# remote.origin.url=https://elmatiaaa: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@github.com/elmatiaaa/prosaindata.git
# remote.origin.fetch=+refs/heads/*:refs/remotes/origin/*

# %%
# !pwd
# Out:
# /content/drive/MyDrive/prosaindata/tugas

# %%
# %cd /content/drive/MyDrive/prosaindata
# Out:
# /content/drive/MyDrive/prosaindata

# %%
# !jupyter-book build tugas/
# Out:
# Running Jupyter-Book v0.15.1
# Source Folder: /content/drive/MyDrive/prosaindata/tugas
# Config Path: /content/drive/MyDrive/prosaindata/tugas/_config.yml
# Output Path: /content/drive/MyDrive/prosaindata/tugas/_build/html
# Running Sphinx v5.0.2
# [etoc] Changing master_doc to 'intro'
# loading pickled environment... checking bibtex cache... up to date
# done
# ...

# %%
# !pip install ghp-import
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pwd
# Out:
# /content/drive/MyDrive/prosaindata

# %%
# %cd /content/drive/MyDrive/prosaindata/tugas
# Out:
# /content/drive/MyDrive/prosaindata/tugas

# %%
# !ghp-import -n -p -f _build/html
# Out:
# Enumerating objects: 22, done.
# Counting objects: 100% (22/22), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (13/13), done.
# Writing objects: 100% (13/13), 107.19 KiB | 4.29 MiB/s, done.
# Total 13 (delta 7), reused 0 (delta 0)
# remote: Resolving deltas: 100% (7/7), completed with 7 local objects.
# To https://github.com/elmatiaaa/prosaindata.git
#    4d90090..c0780a5  gh-pages -> gh-pages
